# %% [markdown]
# # Data Analysis in Python with IPL Data

# %% [markdown]
# # Problem Statement

# %% [raw]
# The dataset consists of the information about people boarding the famous IPL(Indian Premier League) .
# Various variables present in the dataset includes season, city(venue), match between the teams, team which one the toss, match winning team etc.
# The dataset comprises of 696 observations of 18 columns. Below is a table showing names of all the columns and their description.

# %% [markdown]
# # Questions:
# How many matches we’ve got in the dataset?
#
#
# How many seasons we’ve got in the dataset?
#
# Which Team had won by maximum runs?
#
# Which Team had won by maximum wicket?
#
# Which Team had won by closest Margin (minimum runs)?
#
# Which Team had won by minimum wicket?
#
# Which Season had most number of matches?
#
# Which IPL Team is more successful?
#
# Has Toss-winning helped in winning matches?

# %% [markdown]
# # Loading Libraries
#
# loading the Python Modules/Packages/Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
#import matplotlib as mat
import matplotlib.pyplot as plt
import bokeh

# %% [markdown]
# # Reading the data set Of IPL

# %% [markdown]
# Read the input data, let us first define the directory/path in which the input file is present. This is to make sure that the path is stored in a string first before using the same (concatenated) with the file name to read the input csv using pd.read_csv() function.

# %%
ipl1=pd.read_csv("C:/Users/mahesh/Desktop/matches.csv")

# %% [markdown]
# # Get basic information of Data

# %% [markdown]
# # 1. IPL data set shape( number of rows and columns)
#
# the dimension of the dataset — rows and columns

# %%
ipl1.shape
# Out:
# (696, 18)

# %% [markdown]
# # 2. Total number of matches in the dataset?
#
# counts each observation in the data while each observation is a match. So to get the number of matches in our dataset is as same as to get the number of rows in the dataset

# %%
len(ipl1)
# Out:
# 696

# %% [markdown]
# # 3. Summary statistics of data set

# %%
ipl1.describe()
# Out:
#                 id       season  dl_applied  win_by_runs  win_by_wickets
# count   696.000000   696.000000  696.000000   696.000000      696.000000
# mean    974.103448  2012.965517    0.027299    13.472701        3.349138
# std    2143.239623     3.069266    0.163070    23.607994        3.411398
# min       1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%     174.750000  2010.000000    0.000000     0.000000        0.000000
# 50%     348.500000  2013.000000    0.000000     0.000000        3.000000
# 75%     522.250000  2016.000000    0.000000    19.000000        6.000000
# max    7953.000000  2018.000000    1.000000   146.000000       10.000000

# %% [markdown]
# # The different types of data/variables in the given dataset.

# %%
ipl1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 18 columns):
# id                 696 non-null int64
# season             696 non-null int64
# city               689 non-null object
# date               696 non-null object
# team1              696 non-null object
# team2              696 non-null object
# toss_winner        696 non-null object
# toss_decision      696 non-null object
# result             696 non-null object
# dl_applied         696 non-null int64
# winner             693 non-null object
# win_by_runs        696 non-null int64
# win_by_wickets     696 non-null int64
# player_of_match    693 non-null object
# venue              696 non-null object
# umpire1            695 non-null object
# umpire2            695 non-null object
# umpire3            60 non-null object
# dtypes: int64(5), object(13)
# memory usage: 98.0+ KB

# %% [markdown]
# # Data set look

# %%
ipl1.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # Number of IPL seasons in data set
#
# IPL like any other Sports league, happens once in a year and so getting the number of unique years we’ve got in the dataset will tell us how many seasons we’ve got in the dataset.

# %%
ipl1['season'].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018],
#       dtype=int64)

# %% [markdown]
# calculate length of the list that was returned in the above step

# %%
len (ipl1['season'].unique())
# Out:
# 11

# %% [markdown]
# # The most successful IPL Team(most matches won in ipl from 2008-2018)
#
# The most successful IPL team is the team that has won most number of times. Which also means, answer it to this is as same as the above exercise except counting the number of instances in each season, here we’ve to count the number of instances in each winning team

# %%
ipl1['winner'].value_counts().plot.bar()

# %% [markdown]
# # Team won by maximum runs
#
# we can divide the question logically — first we need to find maximum runs, then we can find the row (winning team) with this maximum runs — which would indeed be the team won by maximum runs. I’d like to emphasis here that it’s always important to divide your problem into logical sub-problems or modules and then build Python expressions/codes for those sub-modules finally adding them up to required code that will result in the solution.

# %%
ipl1.winner[ipl1.win_by_runs!=0].mode()
# Out:
# 0    Mumbai Indians
# dtype: object

# %%
ipl1.iloc[ipl1['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %% [markdown]
# #   Team won by maximum wickets
#
# #similar to the calculation off team won by maximum runs

# %%
ipl1.iloc[ipl1['win_by_wickets'].idxmax()]  # team won by maximum wickets
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %%
ipl1.winner[ipl1.win_by_wickets!=0].mode()
# Out:
# 0    Kolkata Knight Riders
# dtype: object

# %% [markdown]
# # Team had won by (closest margin) minimum runs?
#
# the team that was won by the closest margin, we have to do the opposite of what we’ve done in the above steps. But there’s a caveat in that. In Cricket, if the team that’s batting second wins the match (by chasing), it’ll be said “Team second won by x number of wickets” and if the team that’s bowling second (batted first) wins the match (by defending their score), it’ll be said “Team first won by x number of runs”. Hence, the minimum win by runs will always be 0 and the minimum win by wickets will also always be 0 in a tournament since sometimes chasing team or sometimes the team that batted first could win.

# %%
ipl1.iloc[ipl1[ipl1['win_by_runs'].ge(1)].win_by_runs.idxmin()]
# Out:
# id                                                        59
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-05-21
# team1                                         Mumbai Indians
# team2                                 Rising Pune Supergiant
# toss_winner                                   Mumbai Indians
# toss_decision                                            bat
# result                                                normal
# dl_applied                                                 0
# winner                                        Mumbai Indians
# win_by_runs                                                1
# win_by_wickets                                             0
# player_of_match                                    KH Pandya
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %% [markdown]
# # Team had won by (closest margin) minimum wickets?
#
# #similar to the team won minimum runs

# %%
#Which Team had won by minimum wickets?
ipl1.iloc[ipl1[ipl1['win_by_runs'].ge(1)].win_by_wickets.idxmin()]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %% [markdown]
# # Season had most  number of matches
#
# if each row is a match, then counting the number of instances/rows of every season would give us the number of matches for every season.
#
# countplot() function in seaborn does the job right away (without the need of an explicit group_by and count)

# %%
sns.countplot(x='season', data=ipl1)
#plt.show()

# %% [markdown]
# # The most successful IPL Team
#
# The most successful IPL team is the team that has won most number of times. Which also means, answer it to this is as same as the above exercise except counting the number of instances in each season, here we’ve to count the number of instances in each winning team.

# %%
data = ipl1.winner.value_counts()
sns.barplot(y = data.index, x = data, orient='h');

# %% [markdown]
# # Match winners (player of match)

# %%
top_players = ipl1.player_of_match.value_counts()[:50]
fig, ax = plt.subplots()
ax.set_ylim([0,30])
ax.set_ylabel("Count")
ax.set_title("Top player of the match Winners")
top_players.plot.bar()
sns.barplot(x = top_players.index, y = top_players, orient='v'); 
plt.show()

# %% [markdown]
# For those who follow IPL, you might have been wondering the irony now. Chris Gayle, is the most successful IPL player, wasn’t sold in the first round.

# %% [markdown]
# # How many Toss winning teams have won the matches
#
# Has winning toss actually helped in winning the match?
#
# Using our same approach of dividing our problem into chunks — we can separate this question into two — match winner and toss winner if both of them are same — then it’s a success and if not it’s a failure. Before visualizing the outcome, let us first see how the numbers look.

# %%
ss = ipl1['toss_winner'] == ipl1['winner']

ss.groupby(ss).size()
# Out:
# False    339
# True     357
# dtype: int64

# %%
#What's the percentage of it?

round(ss.groupby(ss).size() / ss.count() * 100,2)
# Out:
# False    48.71
# True     51.29
# dtype: float64

# %%
sns.countplot(ss);

# %% [markdown]
# Looks like, Toss winning actually helps in Match winning — or to be statistically right, we could say there’s a correlation between Toss Winning and Match Winning and so we can assume that it helps.

# %% [markdown]
# # Team Performance

# %%
ipl1[ipl1['win_by_runs']>0].groupby(['winner'])['win_by_runs'].apply(np.median).sort_values(ascending = True)
# Out:
# winner
# Gujarat Lions                   1.0
# Kochi Tuskers Kerala           11.5
# Deccan Chargers                14.5
# Sunrisers Hyderabad            15.0
# Delhi Daredevils               17.0
# Kings XI Punjab                19.0
# Rising Pune Supergiant         20.0
# Royal Challengers Bangalore    21.0
# Pune Warriors                  23.0
# Kolkata Knight Riders          23.5
# Chennai Super Kings            24.0
# Mumbai Indians                 25.0
# Rajasthan Royals               26.0
# Rising Pune Supergiants        26.5
# Name: win_by_runs, dtype: float64

# %% [markdown]
# The rising pune supergiants have won most matches by scoring more runs. The team has also won most of time by batting first. The most successful team Mumbai Indians has won most of matches by runs and less by batting second.

# %% [markdown]
# # Teams won by the runs as a bar plot

# %%
fig, ax = plt.subplots()
ax.set_title("Winning by Runs - Team Performance")
sns.boxplot(y = 'winner', x = 'win_by_runs', data=ipl1[ipl1['win_by_runs']>0], orient = 'h'); 
plt.show()

# %% [markdown]
# RCB and MI have won most of matches by scoring huge runs in the won matches. Gujarat lions were the least scorer in the IPL matches. There were some matches by most of teams with nail biting finishes by just 1-5 runs range.

# %% [markdown]
# # Teams won by the wickets as a bar plot

# %%
fig, ax = plt.subplots()
ax.set_title("Winning by Wickets - Team Performance")

sns.boxplot(y = 'winner', x = 'win_by_wickets', data=ipl1[ipl1['win_by_wickets']>0], orient = 'h');
plt.show()

# %%
most of the teams have won matches by batting second. The matches won by KKR, SRH, MI, DD,RCB,CSK RR have won matches without any loss of wickets.
there were some matches with nailbiting finishes (won by just 1 wicket) by KKR, SRH, CSK.
